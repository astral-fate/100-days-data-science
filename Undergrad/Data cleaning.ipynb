# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import scipy.stats

# %%
# Read the Excel file
df = pd.read_excel('undergrad.xlsx')

# Convert the data to CSV format
df.to_csv('undergrad.csv', index=False)

# Read the CSV file
df = pd.read_csv('undergrad.csv')

# %%
df['التخصص'].unique()
# Out:
# array(['تطوير الويب', 'شبكات وأمن المعلومات', 'علوم الحاسب',
#        'تقنية المعلومات والحوسبة ITC', 'الحوسبة والأعمال'], dtype=object)

# %% [markdown]
# # الجنس

# %%
df['الجنس'].unique()
# Out:
# array(['أنثى', 'ذكر'], dtype=object)

# %%
df['الجنس']
# Out:
# 0     أنثى
# 1     أنثى
# 2     أنثى
# 3     أنثى
# 4      ذكر
#       ...
# 64    أنثى
# 65    أنثى
# 66     ذكر
# 67     ذكر
# 68    أنثى
# Name: الجنس, Length: 69, dtype: object

# %%
# Mapping for social status
sex_dict = {'أنثى': 2, 'ذكر': 1}

# Encode the column values
df['الجنس'] = df['الجنس'].map(sex_dict)

# %%
df['الجنس'].unique()
# Out:
# array([2, 1], dtype=int64)

# %%
df['الجنس']
# Out:
# 0     2
# 1     2
# 2     2
# 3     2
# 4     1
#      ..
# 64    2
# 65    2
# 66    1
# 67    1
# 68    2
# Name: الجنس, Length: 69, dtype: int64

# %%
print("Number of columns:", len(df.columns))
# Out:
# Number of columns: 9

# %%
df.columns
# Out:
# Index(['طابع زمني', 'الاسم الكامل', 'الجنس', 'الرقم الجامعي', 'الفرع',
#        'التخصص',
#        'ماهي المعسكرات أو الشهادات التي تحتاجها كطالب خريج والتي تؤهلك للدخول لسوق العمل بسهولة من خلال تجربتك؟',
#        'ماهي الجهات التدريبية المهمة التي يحتاجها الطالب في سيرته الذاتية؟',
#        'ماهي الشهادات المهنية والاحترافية التي ترغب في التسجيل بها؟'],
#       dtype='object')

# %% [markdown]
# # الفرع

# %%
df['الفرع'].unique()
# Out:
# array(['الرياض', 'الدمام', 'جدة', 'المدينة المنورة', 'الأحساء', 'حائل'],
#       dtype=object)

# %%
# Mapping for social status
reg_dict = {'الرياض': 1, 
            'جدة': 2,
            'الدمام': 3,
            'الأحساء': 4,
            'حائل': 5,
            'المدينة المنورة': 6,
            
           }

# Encode the column values
df['الفرع'] = df['الفرع'].map(reg_dict)

# %%
df['الفرع'].unique()
# Out:
# array(['الرياض', 'الدمام', 'جدة', 'المدينة المنورة', 'الأحساء', 'حائل'],
#       dtype=object)

# %%
# Rename the column to 'Certificate'
df.rename(columns={'ماهي المعسكرات أو الشهادات التي تحتاجها كطالب خريج والتي تؤهلك للدخول لسوق العمل بسهولة من خلال تجربتك؟': 'Certificate'}, inplace=True)

# %% [markdown]
# # التعليم

# %%
df['التخصص'].unique()
# Out:
# array(['تطوير الويب', 'شبكات وأمن المعلومات', 'علوم الحاسب',
#        'تقنية المعلومات والحوسبة ITC', 'الحوسبة والأعمال'], dtype=object)

# %%
edu_dict = {
    'علوم الحاسب': 1,
    'تقنية المعلومات والحوسبة ITC': 2,
    'شبكات وأمن المعلومات': 3,
    'الحوسبة والأعمال': 4,
    'تطوير الويب': 5
    
    }

df['التخصص'] = df['التخصص'].map(edu_dict)

# %%
df['التخصص'].unique()
# Out:
# array([5, 3, 1, 2, 4], dtype=int64)

# %% [markdown]
# # الشهادة المهنية

# %%
df['Certificate'].unique()
# Out:
# array(['Aws,apple', 'دورات امن شبكات وماتليها لتخصص الحاسب', 'CCNA',
#        'شهادة الخبره ',
#        'شهادات بالأمن السيبراني وشهادات متطورة بالشبكات وشهادات بالاختراق الأخلاقي',
#        'Google Data Analytics Professional Certificate', 'معسكرات برمجة ',
#        'CCNA, SECURITY ',
#        'معسكرات في مجالات تقنية مثل برمجة التطبيقات والويب، تحليل البيانات وغيرها من المعسكرات اونلاين التي تؤهل الطلاب لسوق العمل في مجالاتهم وتكسبهم خبرة تؤهلهم للحصول على وظيفة بعد التخرج ',
#        'التدريب علي المجال و تعينا في شركات تدريب ',
#        'شهادة جامعيه وشهادات دورات تطوير للتخصص ', 'Cloud computing ',
#        'CCNA, Security+, SOC', 'شهادة امن سيبارني من شركة سيسكو ',
#        'المتطابقة مع مستقبل مثال معسكرات للميتافيرس ',
#        'CCNA and CCNP والدورات التي يقدمها معسكر طويق ',
#        'CCNA, Security+, A+', 'CompTA A+ , Sec+ , CCNP , CCNA ',
#        'الامن السيبراني / SAP',
#        'الامن السيبراني - الذكاء الاصطناعي - هندسة برمجيات',
# ...

# %%
# Mapping dictionary for subcategories
subcategory_mapping = {
    
    
    'PMP': ['PMP', 'مجال ادارة المشاريع و البنية التحتية لتقنية المعلومات و المعماريه في علوم الحاسب خصوصاً ان هذه المجالات ليست مطروحه اكاديمياً بكثافه ولكن قد يوجد بعض الترابط وهذا ماوجدته في عملي الحالي'],
    
    
    
    'Web Development': ['تطوير برمجيات الموبايل',
                        'معسكرات حضورية لتعلم تطوير ويب',
                        'Software Development',
                        'Aws,apple',
                        'الامن السيبراني - الذكاء الاصطناعي - هندسة برمجيات',
                        'على حسب ميول الطالب في اي مجال، انا اخترت مجال تطوير التطبيقات ( بلغة الدارت Flutter ) فحتجت ان اخد عدة دورات من اليودمي لتنشأني بشكل صحيح للتطوير والتصميم في هذه اللغة '
                        
                        
                        ],
    
    
    'Networking': ['Networking', 'CCNA', 'CCNP', 'CCIE', 'JNCIS-SEC', 'HCIA DC', 'Network and Cybersecurity certifications', 'CCNA, Security+', 'CCNA& CCNP', 'CCNA & CCNB', 'CCNA, Security+, A+', 'CompTA A+ Sec+ CCNP CCNA', 'CCNA\nCCNP\nCCIE\nJNCIS-SEC\nHCIA DC', 
                   'دورات امن شبكات وماتليها لتخصص الحاسب',
                   'شهادة امن سيبارني من شركة سيسكو',
                   'دورات كومباتيا واي ام بي ومابكروسوفت',
                   'دورات امن شبكات وماتليها لتخصص  الحاسب',
                   'CCNA',
                   'CCNA & CCNB', 'CHFI',
                   'الامن السيبراني / SAP',
                   'شهادات بالأمن السيبراني وشهادات متطورة بالشبكات وشهادات بالاختراق الأخلاقي',
                   'Ccna', 'CcnA, security ,mos, ',
                   'امن سيبراني',
                   'يوجد الكثير من الشهادات التي من الممكن أن تساعدني في مستقبلي الوظيفي، مثل شهادات سيسكو و شهادات Comptia, و شهادات coursera أيضا '
                   
                   
                   
                   
                   
                   
                   
                   
                   ],
    
    
    
    'Bootcamps': [ 'المتطابقة مع مستقبل مثال معسكرات للميتافيرس',
                  'معسكرات طويق والمبادرات الأخرى المتعلقة بها وأكاديمية أبل للمطورين' ,
                  'معسكر طويق' , 
                  'معسكرات برمجة' ,
                   'معسكرات طويق' ,
                   'معسكرات همة الرقمية ، معسكر ابل ',
                   'معسكرات الامن السيبراني و امن المعلومات بشكل عام',
                   'معسكرات تدريبيه عمليه لأخذ أفضل صورة عن سوق العمل الفعلي وتنشئ شخص ذو خبره واحترافيه في العمل. ',
                   'معسكرات في مجالات تقنية مثل برمجة التطبيقات والويب، تحليل البيانات وغيرها من المعسكرات اونلاين التي تؤهل الطلاب لسوق العمل في مجالاتهم وتكسبهم خبرة تؤهلهم للحصول على وظيفة بعد التخرج ',
                   'دورات في تخصص it',
                   'شهادات ومعسكرات الامن السيبراني',
                   'شهاده Cisco ccna CompTia A+ ومعرفه استخدام برامج الاوفيس',
                   'دورات امن سبراني او دورات فلاتر او دورات في البرمجه او معسكرات',
                   'حضور مؤتمرات ومعارض تخص الشبكات، اقامة دورات تدريبية من الجامعة واتاحة المواد اللازمة مثل اجهزة الشبكة والاسلاك وغيرها وجعل الطالب يقوم بالتجربة بنفسه، عمل مسابقات وتحديات بين الطالب لحلّ مهام متنوعة، التدريب في شركات متنوعة (يفترض ان تتعاون الجامعة مع بعض الشركات للتدريب لمدة سنة على الاقل لتمكين الطالب) ، لقيت صعوبة في التطبيق العملي لما تعلمته في الجامعة لان المحاضرات كانت غالبا عن بعد.',
                   'معسكرات اكاديمية طويق'
                   
                   
                   
                  
                  
                  ],
    
    
    
    'Career Development': ['دورات تطويرية وتأهيلية تخص التخصص',
                           'ان الدراسه وحدها ليست كافية لتؤهل الخريج لسوق العمل بالذات في جامعتنا يعتمد على التعليم الذاتي واغلب المحاضرات اونلاين نحتاج معسكرات ودورات و شهادات لنستفيد منها لان الشهادة الجامعية ليست كل شي توجد دورات كثيرة لشركات قويه مثل سابك و سيسكو …في تخصصنا يوجد مجالات كثيره ومسارات متعدده وبعد التخرج نحس اننا ضايعين مو عارفين اي مجال احنا مبدعين فيه لاننا ماعندنا معلومات غير الكتب الي درسناها بالجامعة اتمنى توجد دورات في كل المجالات الامن السيبراني الذكاء الاصطناعي التحقيق الرقمي البرمجه الشبكات لتخريج طلاب مميزين وسوف ينعكس على الجامعة', 
                           'شهاده الايلتس توفل ستيب', 
                           'دورات تطويرية وتأهيلية تخص التخصص' ,
                           'شهادة الخبره',
                            'شهاده الايلتس توفل ستيب',
                             'شهادة الخبره',
                             'شهادة جامعيه وشهادات دورات تطوير للتخصص',
                             'جميع الشهادات ضمن نطاق التخصص',
                             'التدريب علي المجال و تعينا في شركات تدريب',
                             'ان الدراسه وحدها ليست كافية لتؤهل الخريج لسوق العمل بالذات في جامعتنا يعتمد على التعليم الذاتي واغلب المحاضرات اونلاين نحتاج معسكرات ودورات و شهادات لنستفيد منها لان الشهادة الجامعية ليست كل شي توجد دورات كثيرة لشركات قويه مثل سابك و سيسكو ، ارامكو …في تخصصنا يوجد مجالات كثيره ومسارات متعدده وبعد التخرج نحس اننا ضايعين مو عارفين اي مجال احنا مبدعين فيه لاننا ماعندنا معلومات غير الكتب الي درسناها بالجامعة اتمنى توجد دورات في كل المجالات الامن السيبراني الذكاء الاصطناعي التحقيق الرقمي البرمجه الشبكات لتخريج طلاب مميزين وسوف ينعكس على الجامعة ',
                             'ليس لدي فكره'
                             
                             
                             
                           
                           
                           ],
    
    
    'AI and Data Analytics': ['Google Data Analytics Professional Certificate', 
                              'AI', 'Cloud computing', 
                              'aws',
                              'دورات في الذكاء الاصطناعي',
                              'كل مايخص الامن السيبراني وتقنيه الشبكات وقواعد البيانات',
                              'Orcale'
                              ],
    
    
    
    'Other': []  # Default category for unclassified text
}

# Function to categorize the text into subcategories
def categorize_text(text):
    for category, keywords in subcategory_mapping.items():
        for keyword in keywords:
            if keyword in text:
                return category
    return 'Other'

# Apply the categorization function to the '5- الشهادة المهنية (ان وجد)' column
df['المعسكرات والشهادات اللازمة'] = df['Certificate'].apply(categorize_text)

# %%
# Print the DataFrame with the 'Subcategory' column equal to 'Other'
df[df['المعسكرات والشهادات اللازمة'] == 'Other'][['Certificate', 'المعسكرات والشهادات اللازمة']]
# Out:
# Empty DataFrame
# Columns: [Certificate, المعسكرات والشهادات اللازمة]
# Index: []

# %%
# Print the DataFrame with the 'Subcategory' column equal to 'Other'
df[df['المعسكرات والشهادات اللازمة'] == 'AI and Data Analytics'][['Certificate', 'المعسكرات والشهادات اللازمة']]
# Out:
#                                           Certificate  \
# 5      Google Data Analytics Professional Certificate
# 11                                   Cloud computing
# 34  كل مايخص الامن السيبراني وتقنيه الشبكات وقواعد...
# 63                          دورات في الذكاء الاصطناعي
# 68                                   Cloud computing
#
#    المعسكرات والشهادات اللازمة
# 5        AI and Data Analytics
# 11       AI and Data Analytics
# 34       AI and Data Analytics
# 63       AI and Data Analytics
# 68       AI and Data Analytics

# %%
# Print the DataFrame with the 'Subcategory' column equal to 'Other'
df[df['المعسكرات والشهادات اللازمة'] == 'Networking'][['Certificate', 'المعسكرات والشهادات اللازمة']]
# Out:
#                                           Certificate  \
# 1               دورات امن شبكات وماتليها لتخصص الحاسب
# 2                                                CCNA
# 4   شهادات بالأمن السيبراني وشهادات متطورة بالشبكا...
# 7                                     CCNA, SECURITY
# 12                               CCNA, Security+, SOC
# 13                   شهادة امن سيبارني من شركة سيسكو
# 15     CCNA and CCNP والدورات التي يقدمها معسكر طويق
# 16                                CCNA, Security+, A+
# 17                    CompTA A+ , Sec+ , CCNP , CCNA
# 18                              الامن السيبراني / SAP
# 20                         Networking, cybersecurity
# 22               CCNA\nCCNP\nCCIE\nJNCIS-SEC\nHCIA DC
# 24  CEH certificate - NSE4 Certificate - MCSA Cert...
# 25                                         CCNA& CCNP
# 35  CCNA, Security+, Network+, CHFI, LINUX+, CySA,...
# 36               دورات كومباتيا واي ام بي ومابكروسوفت
# ...

# %%
# Print the DataFrame with the 'Subcategory' column equal to 'Other'
df[df['المعسكرات والشهادات اللازمة'] == 'Bootcamps'][['Certificate', 'المعسكرات والشهادات اللازمة']]
# Out:
#                                           Certificate  \
# 6                                      معسكرات برمجة
# 8   معسكرات في مجالات تقنية مثل برمجة التطبيقات وا...
# 14       المتطابقة مع مستقبل مثال معسكرات للميتافيرس
# 21  معسكرات طويق والمبادرات الاخرى المتعلقة فيها و...
# 23                                       معسكرات طويق
# 27                                         معسكر طويق
# 32  معسكرات الامن السيبراني و امن المعلومات بشكل عام
# 33  معسكرات تدريبيه عمليه لأخذ أفضل صورة عن سوق ال...
# 37  شهاده Cisco ccna CompTia A+ ومعرفه استخدام برا...
# 38                   معسكرات همة الرقمية ، معسكر ابل
# 41  حضور مؤتمرات ومعارض تخص الشبكات، اقامة دورات ت...
# 42                                         معسكر طويق
# 45                                   دورات في تخصص it
# 46                                        معسكر طويق
# 48                                       معسكرات طويق
# 53                   شهادات ومعسكرات الامن السيبراني
# ...

# %%
# Print the DataFrame with the 'Subcategory' column equal to 'Other'
df[df['المعسكرات والشهادات اللازمة'] == 'Web Development'][['Certificate', 'المعسكرات والشهادات اللازمة']]
# Out:
#                                           Certificate  \
# 0                                           Aws,apple
# 19  الامن السيبراني - الذكاء الاصطناعي - هندسة برم...
# 31  على حسب ميول الطالب في اي مجال، انا اخترت مجال...
# 43                               Software Development
# 49                             تطوير برمجيات الموبايل
# 50  معسكرات حضورية لتعلم تطوير ويب ، شهادة خبرة وت...
#
#    المعسكرات والشهادات اللازمة
# 0              Web Development
# 19             Web Development
# 31             Web Development
# 43             Web Development
# 49             Web Development
# 50             Web Development

# %%
# Print the DataFrame with the 'Subcategory' column equal to 'Other'
df[df['المعسكرات والشهادات اللازمة'] == 'Career Development'][['Certificate', 'المعسكرات والشهادات اللازمة']]
# Out:
#                                           Certificate  \
# 3                                       شهادة الخبره
# 9          التدريب علي المجال و تعينا في شركات تدريب
# 10           شهادة جامعيه وشهادات دورات تطوير للتخصص
# 26  ان الدراسه وحدها ليست كافية لتؤهل الخريج لسوق ...
# 29                                       ليس لدي فكره
# 30                     جميع الشهادات ضمن نطاق التخصص
# 62                  دورات تطويرية وتأهيلية تخص التخصص
# 64                            شهاده الايلتس توفل ستيب
#
#    المعسكرات والشهادات اللازمة
# 3           Career Development
# 9           Career Development
# 10          Career Development
# 26          Career Development
# 29          Career Development
# 30          Career Development
# 62          Career Development
# 64          Career Development

# %%
# Rename the column to 'Certificate'
df.rename(columns={'ماهي الجهات التدريبية المهمة التي يحتاجها الطالب في سيرته الذاتية؟': 'جهات التدريب'}, inplace=True)

# %%
# Rename the column to 'Certificate'
df.rename(columns={'ماهي الشهادات المهنية والاحترافية التي ترغب في التسجيل بها؟': 'الشهادات المهنية'}, inplace=True)

# %%
df
# Out:
#     الجنس            الفرع  التخصص  \
# 0       2           الرياض       5
# 1       2           الدمام       4
# 2       2           الرياض       4
# 3       2           الرياض       1
# 4       1           الرياض       4
# ..    ...              ...     ...
# 64      2           الدمام       4
# 65      2           الدمام       2
# 66      1           الرياض       4
# 67      1           الرياض       1
# 68      2  المدينة المنورة       1
#
#                                           Certificate  \
# 0                                           Aws,apple
# 1               دورات امن شبكات وماتليها لتخصص الحاسب
# 2                                                CCNA
# 3                                       شهادة الخبره
# 4   شهادات بالأمن السيبراني وشهادات متطورة بالشبكا...
# ..                                                ...
# 64                            شهاده الايلتس توفل ستيب
# 65                                           CCNA\nAI
# ...

# %%
# Mapping dictionary for subgroups
subcategory_mapping = {
   
    'Organizations and Companies': [
        'العمل في شركات مختصه بالتقنيه وعلوم الحاسب',
        'الشركات والمؤسسات والجامعات  المعترف بها',
        'مؤسسة مسك ، مركز طويق ، الشركات المهتمة بمجال الأمن والشبكات',
        'اي جهه يوجد بها قسم IT',
        'شهادات من شركات تقنية، العمل او التدريب عن بعد',
        'الخبره',
        'مجموعات تنفذ مشاريع',
        'Any IT or networking organizations',
        'بكل اختصار الشركات التي تعطي خبرة عملية اكثر في مجالات ومسارات محددة',
        'كل جهاه معنية بعلوم الحاسب تطويره و تقنياته',
        'تدريب في شركة تقنيه معلومات IT help desk',
        'اي جهة معترفة في مجال تقنية المعلومات',
       
        'جميع شركات التقنية',
        'الشركات المتخصصة في المجال والوزارات المخصصة لمجال العمل',
        'تدريب في شركة تقنيه معلومات IT help desk',
        
        'Networking certification',
        'AOU',
        'اي جهة معروفة لها دور كبير ومهم وانجازات في تقنية المعلومات والتي توفر المعلومات الكاملة التي يحتاجها الطالب في التدريب',
        'جميع جهات التدريب التي تضيف الطالب خبرة',
        'جهات تدعم شهادات cisco,',
        'جهة تدعم شهادات سيسكو، تدريب عملي',
        'شركات التقنيه',
        'الشركات المعتمدة رسميا',
        'الشركات',
        'القطاع الخاص',
        'جميع الجهات سواء خاصه او حكومية',
        'كل جهه معنية بعلوم الحاسب تطويره و تقنياته',
        'شركات، مستشفيات',
        'تكون جهه معتمده وتشرح بشكل جيد',
        'الجهات المعتمدة رسميا',
        'ارامكو',
        'اي جهه تقدم تدريب على لغات برمجه جديده',
        'اي جهه تقدم تدريب  على لغات  برمجه جديده',
        'الدورات التدريبيه والمهارات الشخصيه والعمل التطوعي',
        'دورات تعليمية'
        
        
        
        
        
        
        
        
        
    ],
    'Government Institutions': [
        'الشركات التقنية - الهيئات والوزارات',
        'سدايا . منشآت',
        'أكاديمية طويق',
        'مثل سدايا',
        'صندوق الاستثمارات العامة والشركات والهيئات التي تندرج تحتها أيضاً هيئات الوزارات ومن الممكن إن وجدت الفرصة معسكر طويق للأمن السيبراتي',
        'هيئة الامن السيبراني ، سدايا ، STC ، روشن ، هيئة الاتصالات',
        'جهات حكومية او اماكن تدرب بها',
       
        'هيئة الامن السيبراني ، سدايا ، STC ، روشن ، هيئة الاتصالات',
        'شلمبرجير - STC - ارامكو - سدايا - وغيرها من الشركات الكبرى',
        'جامعة الملك سعود، STC، علم',
        'جهات حكومية او اماكن تدرب بها',
        'أكاديمية طويق',
        'الاتصالات السعودية والذكاء الاصطناعي',
        'هيئة الامن السيبراني ، سدايا ، STC ، روشن ، هيئة الاتصالات',

        'Capture the flag ( CTF ). معسكر طويق الامن السيبراني.',
        'سدايا',
        'Capture the flag ( CTF ). معسكر طويق الامن السيبراني.',
        'سدايا- هيئة الامن السيبراني- هيئة الاتصالات وتقنية المعلومات',
        'اكاديميات الإتحاد السعودي للأمن السيبراني مثل طويق و مطوري ابل ودوراتهم متوفره اونلاين عبر منصة سطر وانصح قسم الانشطه الطلابيه بارسال بريد عن دوره معينه مثلاً لكل الطلاب والطالبات خصوصاً انها مجانيه ( هذا الشيء يحدث في العمل ) و انصح ايضاً بمشاركة مواقع مكاتب المعرفه للشركات العالميه مثل cisco community او IBM Knowledge Base وغيره كثير و معهد اباد في الرياض و لاحظت زملاء عمل يحضرون الدورات هناك بكثره و اسعاره مناسبه، دورات مسك ايضاً'
    ],
    'big tech companies': [
        'CISCO',
        'Google Data Analytics Professional Certificate',
        'Cisco , fortinet , stc , others',
        'Huawei, Cisco, Apple',
        'CCNA',
        'Cisco , Aramco , Sabic , Banks , SDAIA , CST , STC , etc',
        'Cisco, Comptia, IBM, Google',
        'جوجل',
        'cisco', 'Cisco', 'CISCO',
        'يتدرب في شركات تخص مجاله مثل سيسكو ومايكروسوفت تخصني كطالب شبكات. '
    ],
    'Other': [
    
        'الدورات التدريبيه والمهارات الشخصيه والعمل التطوعي',
        '—————', 'لا اعلم',
        'I have no answer',
        'اي', 
        '....',
        'جميع الجهات المهمة بالرياض لا توجد جهات بالشرقية و ليس الجميع بإمكانه الانتقال لمدينة اخرى للتدريب'
        
  
    ]
}

# Function to categorize the text into subcategories
def categorize_text(text):
    for category, keywords in subcategory_mapping.items():
        for keyword in keywords:
            if keyword in text:
                return category
    return 'Other'

# Apply the categorization function to the 'جهات التدريب' column
df['الجهات التدريبية'] = df['جهات التدريب'].apply(categorize_text)

# %%
# Print the DataFrame with the 'Subcategory' column equal to 'Other'
df[df['الجهات التدريبية'] == 'Other'][['جهات التدريب', 'الجهات التدريبية']]
# Out:
#                                          جهات التدريب الجهات التدريبية
# 16                                                 اي            Other
# 18  جميع الجهات المهمة بالرياض لا توجد جهات بالشرق...            Other
# 29                                            لا اعلم            Other
# 35                                               ....            Other
# 51                                              —————            Other
# 52                                  I have no answer             Other
# 56                                           لا اعلم             Other
# 64                                                  _            Other

# %%
# Print the DataFrame with the 'Subcategory' column equal to 'Other'
df[df['الجهات التدريبية'] == 'big tech companies'][['جهات التدريب', 'الجهات التدريبية']]
# Out:
#                                          جهات التدريب    الجهات التدريبية
# 5      Google Data Analytics Professional Certificate  big tech companies
# 13                                              Cisco  big tech companies
# 17                    Cisco , fortinet , stc , others  big tech companies
# 22                              على سبيل المثال Cisco  big tech companies
# 25                                               CCNA  big tech companies
# 40                                              cisco  big tech companies
# 41  يتدرب في شركات تخص مجاله مثل سيسكو ومايكروسوفت...  big tech companies
# 49                                              جوجل   big tech companies
# 54                              Huawei,  Cisco, Apple  big tech companies
# 60                        Cisco\nComptia\nIBM\nGoogle  big tech companies
# 61  Cisco , Aramco , Sabic , Banks , SDAIA , CST ,...  big tech companies
# 65                                              Cisco  big tech companies
# ...

# %%
# Print the DataFrame with the 'Subcategory' column equal to 'Other'
df[df['الجهات التدريبية'] == 'Government Institutions'][['جهات التدريب', 'الجهات التدريبية']]
# Out:
#                                          جهات التدريب         الجهات التدريبية
# 0                                               سدايا  Government Institutions
# 10                                     سدايا . منشآت   Government Institutions
# 11                                              سدايا  Government Institutions
# 12                                      أكاديمية طويق  Government Institutions
# 14                                         مثل سدايا   Government Institutions
# 27                        جامعة الملك سعود، STC، علم   Government Institutions
# 31                      جهات حكومية او اماكن تدرب بها  Government Institutions
# 34                                              سدايا  Government Institutions
# 46  سدايا- هيئة الامن السيبراني- هيئة الاتصالات وت...  Government Institutions
# 48  Capture the flag ( CTF ). معسكر طويق الامن الس...  Government Institutions
# 53  هيئة الامن السيبراني ، سدايا ، STC ، روشن ، هي...  Government Institutions
# ...

# %%
# Print the DataFrame with the 'Subcategory' column equal to 'Other'
df[df['الجهات التدريبية'] == 'Organizations and Companies'][['جهات التدريب', 'الجهات التدريبية']]
# Out:
#                                          جهات التدريب  \
# 1          العمل في شركات مختصه بالتقنيه وعلوم الحاسب
# 2                الشركات التقنية - الهيئات والوزارات
# 3           الشركات والمؤسسات والجامعات  المعترف بها
# 4   مؤسسة مسك ، مركز طويق ، الشركات المهتمة بمجال ...
# 6                                مجموعات تنفذ مشاريع
# 7                              اي جهه يوجد بها قسم IT
# 8     شهادات من شركات تقنية، العمل او التدريب عن بعد
# 9                                             الخبره
# 15   صندوق الاستثمارات العامة والشركات والهيئات ال...
# 19           اي جهه تقدم تدريب  على لغات  برمجه جديده
# 20                Any IT or networking organizations
# 21  بكل اختصار الشركات التي تعطي خبرة عملية اكثر ف...
# 23                              الجهات المعتمدة رسميا
# 24  شلمبرجير - STC - ارامكو - سدايا - وغيرها من ال...
# 26                   جميع الجهات سواء خاصه او حكومية
# 28                                      القطاع الخاص
# ...

# %%
df
# Out:
#     الجنس            الفرع  التخصص  \
# 0       2           الرياض       5
# 1       2           الدمام       4
# 2       2           الرياض       4
# 3       2           الرياض       1
# 4       1           الرياض       4
# ..    ...              ...     ...
# 64      2           الدمام       4
# 65      2           الدمام       2
# 66      1           الرياض       4
# 67      1           الرياض       1
# 68      2  المدينة المنورة       1
#
#                                           Certificate  \
# 0                                           Aws,apple
# 1               دورات امن شبكات وماتليها لتخصص الحاسب
# 2                                                CCNA
# 3                                       شهادة الخبره
# 4   شهادات بالأمن السيبراني وشهادات متطورة بالشبكا...
# ..                                                ...
# 64                            شهاده الايلتس توفل ستيب
# 65                                           CCNA\nAI
# ...

# %%
df['الشهادات المهنية'].unique()
# Out:
# array(['طويق وابل', 'Pmp -ciso-copmuting', 'CCNA - CCNP',
#        'اي شهادة تفيد ',
#        'لايوجد لي علم بالشهادات المحترفة او المتطلبة لسوق العمل',
#        'Google Data Analytics Professional Certificate',
#        'Meta front end and back end certificate ', 'CCNA, eJPT',
#        'التهيئة لسوق العمل في اكثر من مسار تقني مثل مبرمجة التطبيقات و تحليل البيانات والشبكات والذكاء الاصطناعي وغيرها من المجالات التقنية، وايضا شهادات احترافية في المجال نفسه ',
#        'الشهادات والمهنه العمليه', 'شهادة CCNP',
#        'CCNA - Cloud computing - Networking ', 'CCNA, Security+, SOC',
#        'CyberOps Associate ', 'الهندسيه', 'CCNA+CCNP +CISSP+CISM',
#        'CCNA, Security+, A+', 'A+ , sec + , MSCA , CCNP , CCNA , NES ',
#        'CS50 Overall> Microsoft> software development ',
#        'هندسة برمجيات - روبوتات', 'Cissp , ccnp , NSE ',
#        'Comptia A+ \nComptia network+\nComptia security+\nCCNA',
#        'Server+', 'جميع ما يخدم مصلحة العمل',
# ...

# %%
# Mapping dictionary for subcategories
subcategory_mapping = {
    'PMP': ['PMP', 'Pmp -ciso-copmuting', 'PMP'],
    
    
    'Software Development': [
                'Meta front end and back end certificate',
                'CS50 Overall> Microsoft> software development',
                'هندسة برمجيات - روبوتات',
                'البرمجه',
                'لا يوجد شيء معين ولكن اطمح في ان احصل على عدة شهادات في تطوير التطبيقات ولغة دارت تحديداً',
                'Software Development',
               'شهادات متعلقة في تطوير برمجيات الموبايل ك فلاتر',
                'شهادات متعلقة في تطوير برمجيات الموبايل ك فلاتر',
        
        
    ],
    
    
    'Networking': [
        'CCNA - CCNP',
        'OSCP Certificate',
        'CCNA, eJPT',
        'CCNA+CCNP +CISSP+CISM',
        'CTT+, CSM',
        
        'CCNA, Security+, SOC',
        'CyberOps Associate',
        'CCNA',
        'CISM ,CCNA',
        'CCNP',
        'Comptia A+ Comptia Network+',
        'CCNA .CCNP',
        'CCNP - Pentesting - security ++',
        'CCNA - aws cloud - Microsoft Servers',
        'CCNP, NSE4',
        '+Security ، CEH ، CCSK ، CRISC',
        'كل الشهادات الممكنة',
        'Cisco, microsoft',
        'كومباتيا بلس وسيكورتي بلس وغيره',
        'خبير امن سبراني',
        'Server+',
        'Cissp , ccnp , NSE',
        'شهادة ccnp, ccna',
        'Systems Secutity Professional Certified Information (CISSP)',
        
        'CompTia A+, compTia Network+, compTia Security+',
        'Ccna - aws cloud - Microsoft Servers',
        'CCNA & CCNB CISCO Certification',
        'كل شهادات الشبكات سيسكو ومايكروسوفت',
        'سيسكو و اوراكل',
        'Every certification related to Cybersecurity, including ethical hacking, defensive security, and offensive security',
    ],
    
    'AI and Data Analytics': [
        'Google Data Analytics Professional Certificate',
        'كورسيرا ، شهادات تدريبية مقدمة من قوقل',
        'Orcale',
        'Google ,'
    ],
    
    'Career Development': [
        'التهيئة لسوق العمل في اكثر من مسار تقني مثل مبرمجة التطبيقات و تحليل البيانات والشبكات والذكاء الاصطناعي وغيرها من المجالات التقنية، وايضا شهادات احترافية في المجال نفسه',
        'PMP , Togaf , scrum & agile',
      
        'شهادة معتمدة ومعروفة من خارج المملكة لها تأثير في عادم الIT',
        'جميع ما يخدم مصلحة العمل',
        'اعتماد هيئه المهندسين',
        'كل شي مفيد ومطلوب في سوق العمل',
        'الشهادات والمهنه العمليه',
        'الهندسيه',
        'اي شهادة تفيد',
        'جميع الشهادات ضمن نطاق التخصص',
        'ايلتس'
        
        
        
        
    ],
    
       
    'Bootcamps': [
        'طويق وابل',
        'دورات معروفه لشركات كبيره مثل ارامكو و سابك',
        'معسكرات اكاديمية طويق لبرمجة التطبيقات ios وغيرها'
    ],
    
    'Other': [
        'اي شهادة تفيد',
        'لايوجد لي علم بالشهادات المحترفة او المتطلبة لسوق العمل',
        'الشهادات والمهنه العمليه',
        'الهندسيه',
        'كل شي مفيد ومطلوب في سوق العمل',
        'جميع الشهادات ضمن نطاق التخصص',
        'لا يوجد شيء معين ولكن اطمح في ان احصل على عدة شهادات في تطوير التطبيقات ولغة دارت تحديداً',
        'ايلتس',
        
 ],
    
}

# Function to categorize the text into subcategories
def categorize_text(text):
    for category, keywords in subcategory_mapping.items():
        for keyword in keywords:
            if keyword in text:
                return category
    return 'Other'

# Apply the categorization function to the 'الشهادة المهنية (ان وجد)' column
df['الشهادات المهنية اللازمة'] = df['الشهادات المهنية'].apply(categorize_text)

# %%
df['الشهادات المهنية اللازمة']
# Out:
# 0                 Bootcamps
# 1                       PMP
# 2                Networking
# 3        Career Development
# 4                     Other
#               ...
# 64       Career Development
# 65               Networking
# 66               Networking
# 67                      PMP
# 68    AI and Data Analytics
# Name: الشهادات المهنية اللازمة, Length: 69, dtype: object

# %%
# Print the DataFrame with the 'Subcategory' column equal to 'Other'
df[df['الشهادات المهنية اللازمة'] == 'Other'][['الشهادات المهنية', 'الشهادات المهنية اللازمة']]
# Out:
#                                     الشهادات المهنية الشهادات المهنية اللازمة
# 4  لايوجد لي علم بالشهادات المحترفة او المتطلبة ل...                    Other

# %%
# Print the DataFrame with the 'Subcategory' column equal to 'Other'
df[df['الشهادات المهنية اللازمة'] == 'Bootcamps'][['الشهادات المهنية', 'الشهادات المهنية اللازمة']]
# Out:
#                                      الشهادات المهنية الشهادات المهنية اللازمة
# 0                                           طويق وابل                Bootcamps
# 45        دورات معروفه لشركات كبيره مثل ارامكو و سابك                Bootcamps
# 59  معسكرات اكاديمية طويق لبرمجة التطبيقات ios وغيرها                Bootcamps

# %%
# Print the DataFrame with the 'Subcategory' column equal to 'Other'
df[df['الشهادات المهنية اللازمة'] == 'AI and Data Analytics'][['الشهادات المهنية', 'الشهادات المهنية اللازمة']]
# Out:
#                                   الشهادات المهنية الشهادات المهنية اللازمة
# 5   Google Data Analytics Professional Certificate    AI and Data Analytics
# 38                                        Google ,    AI and Data Analytics
# 50         كورسيرا ، شهادات تدريبية مقدمة من قوقل     AI and Data Analytics
# 68                                          Orcale    AI and Data Analytics

# %%
# Print the DataFrame with the 'Subcategory' column equal to 'Other'
df[df['الشهادات المهنية اللازمة'] == 'Networking'][['الشهادات المهنية', 'الشهادات المهنية اللازمة']]
# Out:
#                                      الشهادات المهنية الشهادات المهنية اللازمة
# 2                                         CCNA - CCNP               Networking
# 7                                          CCNA, eJPT               Networking
# 10                                         شهادة CCNP               Networking
# 11               CCNA - Cloud computing - Networking                Networking
# 12                               CCNA, Security+, SOC               Networking
# 13                                CyberOps Associate                Networking
# 15                              CCNA+CCNP +CISSP+CISM               Networking
# 16                                CCNA, Security+, A+               Networking
# 17             A+ , sec + , MSCA , CCNP , CCNA , NES                Networking
# 20                                Cissp , ccnp , NSE                Networking
# 21  Comptia A+ \nComptia network+\nComptia securit...               Networking
# ...

# %%
# Print the DataFrame with the 'Subcategory' column equal to 'Other'
df[df['الشهادات المهنية اللازمة'] == 'Software Development'][['الشهادات المهنية', 'الشهادات المهنية اللازمة']]
# Out:
#                                      الشهادات المهنية الشهادات المهنية اللازمة
# 6            Meta front end and back end certificate      Software Development
# 18     CS50 Overall> Microsoft> software development      Software Development
# 19                            هندسة برمجيات - روبوتات     Software Development
# 31  لا يوجد شيء معين ولكن اطمح في ان احصل على عدة ...     Software Development
# 43                               Software Development     Software Development
# 49    شهادات متعلقة في تطوير برمجيات الموبايل ك فلاتر     Software Development
# 56                                            البرمجه     Software Development

# %%
# Print the DataFrame with the 'Subcategory' column equal to 'Other'
df[df['الشهادات المهنية اللازمة'] == 'PMP'][['الشهادات المهنية', 'الشهادات المهنية اللازمة']]
# Out:
#                الشهادات المهنية الشهادات المهنية اللازمة
# 1           Pmp -ciso-copmuting                      PMP
# 28                          PMP                      PMP
# 67  PMP , Togaf , scrum & agile                      PMP

# %%
df
# Out:
#     الجنس  الفرع  التخصص المعسكرات والشهادات اللازمة  \
# 0       2      1       5             Web Development
# 1       2      3       3                  Networking
# 2       2      1       3                  Networking
# 3       2      1       1          Career Development
# 4       1      1       3                  Networking
# ..    ...    ...     ...                         ...
# 64      2      3       3          Career Development
# 65      2      3       2                  Networking
# 66      1      1       3                  Networking
# 67      1      1       1                         PMP
# 68      2      6       1       AI and Data Analytics
#
#                الجهات التدريبية الشهادات المهنية اللازمة
# 0       Government Institutions                Bootcamps
# 1   Organizations and Companies                      PMP
# 2   Organizations and Companies               Networking
# 3   Organizations and Companies       Career Development
# ...

# %%
# List of columns to be deleted
columns_to_delete = ['الرقم الجامعي', 'طابع زمني', 'الاسم الكامل']

# Use the drop method to delete the columns
df = df.drop(columns=columns_to_delete)

# Print the updated DataFrame
print(df)
# Out:
#     الجنس  الفرع  التخصص المعسكرات والشهادات اللازمة  \
# 0       2      1       5             Web Development
# 1       2      3       3                  Networking
# 2       2      1       3                  Networking
# 3       2      1       1          Career Development
# 4       1      1       3                  Networking
# ..    ...    ...     ...                         ...
# 64      2      3       3          Career Development
# 65      2      3       2                  Networking
# 66      1      1       3                  Networking
# 67      1      1       1                         PMP
# 68      2      6       1       AI and Data Analytics
#
#                الجهات التدريبية الشهادات المهنية اللازمة
# 0       Government Institutions                Bootcamps
# 1   Organizations and Companies                      PMP
# 2   Organizations and Companies               Networking
# 3   Organizations and Companies       Career Development
# ...

# %%
# List of columns to be deleted
columns_to_delete = ['Certificate']

# Use the drop method to delete the columns
df = df.drop(columns=columns_to_delete)

# %%
# List of columns to be deleted
columns_to_delete = ['الشهادات المهنية']

# Use the drop method to delete the columns
df = df.drop(columns=columns_to_delete)

# %%
# List of columns to be deleted
columns_to_delete = ['جهات التدريب']

# Use the drop method to delete the columns
df = df.drop(columns=columns_to_delete)

# %%
df
# Out:
#     الجنس  الفرع  التخصص المعسكرات والشهادات اللازمة  \
# 0       2      1       5             Web Development
# 1       2      3       4                  Networking
# 2       2      1       4                  Networking
# 3       2      1       1          Career Development
# 4       1      1       4                  Networking
# ..    ...    ...     ...                         ...
# 64      2      3       4          Career Development
# 65      2      3       2                  Networking
# 66      1      1       4                  Networking
# 67      1      1       1                         PMP
# 68      2      6       1       AI and Data Analytics
#
#                الجهات التدريبية الشهادات المهنية اللازمة
# 0       Government Institutions                Bootcamps
# 1   Organizations and Companies                      PMP
# 2   Organizations and Companies               Networking
# 3   Organizations and Companies       Career Development
# ...

# %%
df
# Out:
#     الجنس            الفرع  التخصص  \
# 0       2           الرياض       5
# 1       2           الدمام       4
# 2       2           الرياض       4
# 3       2           الرياض       1
# 4       1           الرياض       4
# ..    ...              ...     ...
# 64      2           الدمام       4
# 65      2           الدمام       2
# 66      1           الرياض       4
# 67      1           الرياض       1
# 68      2  المدينة المنورة       1
#
#                                           Certificate  \
# 0                                           Aws,apple
# 1               دورات امن شبكات وماتليها لتخصص الحاسب
# 2                                                CCNA
# 3                                       شهادة الخبره
# 4   شهادات بالأمن السيبراني وشهادات متطورة بالشبكا...
# ..                                                ...
# 64                            شهاده الايلتس توفل ستيب
# 65                                           CCNA\nAI
# ...

# %%
excel_file_path = 'undergrad23.xlsx'  # Replace with the desired file path

# Save the DataFrame to an Excel file
df.to_excel(excel_file_path, index=False)

print(f"DataFrame saved to {excel_file_path}")
# Out:
# DataFrame saved to undergrad23.xlsx

# %%
# Assuming 'df' is your DataFrame
# Define the columns you want to save
columns_to_save = ['Certificate', 'المعسكرات والشهادات اللازمة']

# Create a new DataFrame containing only the selected columns
selected_columns_df = df[columns_to_save]

# Specify the file path where you want to save the Excel file
output_file_path = 'Boot&Cerc.xlsx'

# Save the selected columns to an Excel file
selected_columns_df.to_excel(output_file_path, index=False)

# %%
import pandas as pd

# Assuming 'df' is your DataFrame
# Define the columns you want to save
columns_to_save = ['جهات التدريب', 'الجهات التدريبية']

# Create a new DataFrame containing only the selected columns
selected_columns_df = df[columns_to_save]

# Specify the file path where you want to save the Excel file
output_file_path = 'training_places.xlsx'

# Save the selected columns to an Excel file
selected_columns_df.to_excel(output_file_path, index=False)

# %%
# Assuming 'df' is your DataFrame
# Define the columns you want to save
columns_to_save = ['الشهادات المهنية', 'الشهادات المهنية اللازمة']

# Create a new DataFrame containing only the selected columns
selected_columns_df = df[columns_to_save]

# Specify the file path where you want to save the Excel file
output_file_path = 'ProfCerts.xlsx'

# Save the selected columns to an Excel file
selected_columns_df.to_excel(output_file_path, index=False)
